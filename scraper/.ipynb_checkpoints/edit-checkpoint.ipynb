# %%
import pandas as pd

# %%
df = pd.read_csv("professors.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0                  name                rating  \
# 0              0  Dorothy Goldsborough  QUALITY2.617 ratings
# 1              1        Adele Casaschi  QUALITY3.921 ratings
# 2              2    Krishna Lamichhane   QUALITY4.32 ratings
# 3              3        Curtis Ikehara   QUALITY4.76 ratings
# 4              4            Jan Huston   QUALITY2.04 ratings
# ...          ...                   ...                   ...
# 2479        2479        Gregory Gillis   QUALITY0.00 ratings
# 2480        2480          Chris Rachal  QUALITY4.497 ratings
# 2481        2481       Andrew Rominger   QUALITY0.00 ratings
# 2482        2482         Boris Murmann   QUALITY5.01 ratings
# 2483        2483              Ivan Wen   QUALITY1.01 ratings
#
#              department feedback                         school
# 0             Sociology      NaN  University of Hawaii at Manoa
# 1             Chemistry      NaN  University of Hawaii at Manoa
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                  name                rating         department  \
# 0           0  Dorothy Goldsborough  QUALITY2.617 ratings          Sociology
# 1           1        Adele Casaschi  QUALITY3.921 ratings          Chemistry
# 2           2    Krishna Lamichhane   QUALITY4.32 ratings        Engineering
# 3           3        Curtis Ikehara   QUALITY4.76 ratings   Computer Science
# 4           4            Jan Huston   QUALITY2.04 ratings  Political Science
#
#   feedback                         school
# 0      NaN  University of Hawaii at Manoa
# 1      NaN  University of Hawaii at Manoa
# 2      NaN  University of Hawaii at Manoa
# 3      NaN  University of Hawaii at Manoa
# 4      NaN  University of Hawaii at Manoa

# %%
df['rating'] = df['rating'].str.extract('(\d+\.\d+)').astype(float)  # Extracts the number as float
df['rating'] = df['rating'].apply(lambda x: float(str(x)[:3]))
df.head()
# Out:
#    Unnamed: 0                  name  rating         department feedback  \
# 0           0  Dorothy Goldsborough     2.6          Sociology      NaN
# 1           1        Adele Casaschi     3.9          Chemistry      NaN
# 2           2    Krishna Lamichhane     4.3        Engineering      NaN
# 3           3        Curtis Ikehara     4.7   Computer Science      NaN
# 4           4            Jan Huston     2.0  Political Science      NaN
#
#                           school
# 0  University of Hawaii at Manoa
# 1  University of Hawaii at Manoa
# 2  University of Hawaii at Manoa
# 3  University of Hawaii at Manoa
# 4  University of Hawaii at Manoa

# %%
df.head()
# Out:
#    Unnamed: 0                  name  rating         department feedback  \
# 0           0  Dorothy Goldsborough     2.6          Sociology      NaN
# 1           1        Adele Casaschi     3.9          Chemistry      NaN
# 2           2    Krishna Lamichhane     4.3        Engineering      NaN
# 3           3        Curtis Ikehara     4.7   Computer Science      NaN
# 4           4            Jan Huston     2.0  Political Science      NaN
#
#                           school
# 0  University of Hawaii at Manoa
# 1  University of Hawaii at Manoa
# 2  University of Hawaii at Manoa
# 3  University of Hawaii at Manoa
# 4  University of Hawaii at Manoa

# %%
df.tail(20)
# Out:
#       Unnamed: 0              name  rating         department feedback  \
# 2464        2464     T Kira Madden     5.0            English     100%
# 2465        2465  Jessica Ackerley     5.0              Music     100%
# 2466        2466      Kenneth Pugh     0.0             Speech      NaN
# 2467        2467         Jay Stout     4.7      Communicology      97%
# 2468        2468        Sean Smith     4.8         Philosophy      88%
# 2469        2469       Inessa Love     4.4          Economics      92%
# 2470        2470     Ibrahim Aoude     3.9     Ethnic Studies      75%
# 2471        2471     Changwon Yang     0.0  Political Science      NaN
# 2472        2472     Olivia Waring     0.0          Languages      NaN
# 2473        2473       Julie Iezzi     4.5            Theater      NaN
# 2474        2474   Akhilesh Tiwari     0.0           Business     100%
# 2475        2475     Megan Ikemoto     5.0          Education     100%
# ...

# %%
df.to_csv("profs.csv")
